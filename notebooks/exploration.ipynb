# %% [markdown]
# # Exploration notebook
#
# Optional scratch space for exploring the binomial pricer, NN, and RL policy interactively. Core logic should stay in `src/`, not here -- this notebook should only *import and call* functions from `src/`.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))

from src.pricing.binomial import OptionContract, crr_price

c = OptionContract(S0=100, K=100, T=1.0, r=0.05, sigma=0.25, steps=200, option_type='put')
print('American put price:', crr_price(c, american=True))
